# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('Desktop/Anaconda/Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread('wrong/path/doesnot/asdfsffsafs.jpg')

# %%
type(img)
# Out:
# NoneType

# %%
img = cv2.imread('Desktop/Anaconda/Computer-Vision-with-Python/DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB ----> R,B,G
#OPENCV ---------> B,G,R

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)
# Display of the original image

# %%
img_gray = cv2.imread('Desktop/Anaconda/Computer-Vision-with-Python/DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.min()
# Out:
# 1

# %%
img_gray.max()
# Out:
# 209

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap= 'gray')

# %%
plt.imshow(img_gray,cmap= 'magma')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img= cv2.resize(fix_img,(1000,500))
#re-sizing the existing image to a new resolution

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5  
# width ratio is reduced to 50%
h_ratio = 0.5
# height ratio is reduced to 50%

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# the result of the fix_image(original img) is finally reduced to exactly by half
# Out:
# (650, 975, 3)

# %%
new_img= cv2.flip(fix_img,1)
# flipping the image in your direction we need to pass the parameter in the second order
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('Desktop/Anaconda/Computer-Vision-with-Python/DATA/Flipped_image.jpg',fix_img)
# save the image in the file by just write command
# Out:
# True

# %%
# display the image size to a larger scale
fig = plt.figure(figsize=(12,8))
ax= fig.add_subplot(111)
ax.imshow(fix_img)

# %%
# display the image size to a smaller scale 
fig = plt.figure(figsize=(1,1))
ax= fig.add_subplot(111)
ax.imshow(fix_img)
